# %% [markdown]
# | | |
# |--|--|
# | **Names** | *Raoul Fasel & Bouke Regnerus* |
# | **Group** | *02* |

# %% [markdown]
# # Alzheimer's MRI deep learning

# %%
import math

import json

import numpy as np
import numpy.ma as ma

import scipy as scipy

import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap

from mpl_toolkits.axes_grid1 import make_axes_locatable

import itertools

from sklearn import svm, datasets
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import theano
import theano.tensor as T

import keras
from keras import backend as K
from keras.utils import np_utils

from keras.layers import Input, Dense, Convolution2D, MaxPooling2D, Deconvolution2D, UpSampling2D, Reshape, Flatten, ZeroPadding2D, BatchNormalization, Lambda, Dropout, Activation
from keras.layers import Convolution3D, MaxPooling3D
from keras.models import Model, Sequential
from keras.models import model_from_json

from keras.optimizers import SGD, RMSprop, Adam
from keras.layers.advanced_activations import LeakyReLU
from keras.preprocessing import image

from keras.callbacks import Callback
from keras.models import load_model

from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping

from mpl_toolkits.mplot3d import Axes3D

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder

theano.config.opennp = True

# %%
model_version = 'v4'

channels = 62
img_size_x = 96
img_size_y = 96

batch_size = 32
nb_classes = 3
nb_epoch = 30

c = 0

learning_rate = 0.003
early_stopping_patience = 20

class_names = ["CN", "MCI", "AD"]

# %%
"""Custom CMAP"""
# Choose colormap
binary_cmap = cm.binary

# Get the colormap colors
scan_cmap = binary_cmap(np.arange(cm.binary.N))

# Set alpha
scan_cmap[:,-1] = np.linspace(0, 1, cm.binary.N)

# Create new colormap
scan_cmap = ListedColormap(scan_cmap)

# %%
"""Get Data"""
c = 0
    
def load_dataset():
    
    def load_mri_images(filename):
        global c
        
        data = np.load(filename)
        
        tmp = c
        c = tmp + 1
        
        print 'Loaded image set %d of 32.' %c
        
        return data
    
    def imgwise_2d_scaling(data):
        #loop over patients
        for i in range(len(data)):
            for j in range(len(data[i][0])):
                max_val_2d = np.amax(data[i][0][j])

                data[i][0][j] = data[i][0][j].astype('float32')
                data[i][0][j] /= max_val_2d
                
        print 'Executed imagewise 2d scaling.'

        return data

    def imgwise_3d_scaling(data):
         #loop over patients
        for i in range(len(data)):
            max_val_3d = np.amax(data[i][0])

            data[i][0] = data[i][0].astype('float32')
            data[i][0] /= max_val_3d

        print 'Executed imagewise 3d scaling.'
        
        return data
    
    def reshape_mri_images(data):
        #Reshape the loaded dataset to the appropriate format.
        data = np.expand_dims(data,axis=1)
        data = np.reshape(data, (-1, 1, channels, img_size_x, img_size_y))
        
        print 'Reshaped images.'
        
        return data
    
    def load_mri_labels(filename, train_valid_test):
        data = pd.read_csv(filename)

        data = data.loc[data['train_valid_test'] == train_valid_test]
        
        data = np.asarray(data.diagnosis)
             
        data = data.reshape((-1, 1))
        data = data.astype(np.int64)
        
        #labels start at 1, normalise them to start at 0.
        data = np.subtract(data, 1)
        
        data = np_utils.to_categorical(data, nb_classes)
        
        print 'Loaded labels.'

        return data
    
    train_data = load_mri_images('img_array_train_6k_1.npy')
    for i in range(2,23):
        train_cur = load_mri_images('img_array_train_6k_%d.npy' %i)
        train_data = np.vstack((train_data, train_cur))
    train_data = reshape_mri_images(train_data)
    train_data = imgwise_3d_scaling(train_data)
#     train_data = imgwise_2d_scaling(train_data)
    train_labels = load_mri_labels('adni_demographic_master_kaggle.csv', 0)

    val_data = load_mri_images('img_array_valid_6k_1.npy')
    for i in range(2,6):
        valid_cur = load_mri_images('img_array_valid_6k_%d.npy' %i)
        val_data = np.vstack((val_data, valid_cur))
    val_data = reshape_mri_images(val_data)
    val_data = imgwise_3d_scaling(val_data)
#     val_data = imgwise_2d_scaling(val_data)
    val_labels = load_mri_labels('adni_demographic_master_kaggle.csv', 1)
    
    test_data = load_mri_images('img_array_test_6k_1.npy')
    for i in range(2,6):
        test_cur = load_mri_images('img_array_test_6k_%d.npy' %i)
        test_data = np.vstack((test_data, test_cur))
    test_data = reshape_mri_images(test_data)
    test_data = imgwise_3d_scaling(test_data)
#     test_data = imgwise_2d_scaling(test_data)
    test_labels = load_mri_labels('adni_demographic_master_kaggle.csv', 2)
    
    print 'Done.'
    
    return train_data, train_labels, test_data, test_labels, val_data, val_labels

# %%
def build_cnn(input_var=None):
    global convout1
    
    model = Sequential()

    model.add(Convolution3D(8, 3, 3, 3, name='conv1', input_shape=(1, channels, img_size_x, img_size_y)))
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Convolution3D(8, 3, 3, 3, name='conv2'))
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Convolution3D(8, 3, 3, 3, name='conv3'))
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Flatten())
    
    model.add(Dense(2000, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(500, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(nb_classes, activation='softmax'))

    opt = keras.optimizers.Adadelta()

    model.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy'])
    
    print 'Done building model.'

    return model

# %%
class SGDLearningRateTracker(Callback):
    def on_epoch_end(self, epoch, logs={}):
        optimizer = self.model.optimizer
        lr = K.eval(optimizer.lr * (1. / (1. + optimizer.decay * optimizer.iterations)))
        print str('\nLR: {:.6f}\n').format(float(lr))
    
def fit_model(model, v):
    model_weights_file = 'img_classifier_weights_%s.h5' %v
    epoch_weights_file = 'img_classifier_weights_%s_{epoch:02d}_{val_acc:.2f}.hdf5' %v
    model_file = 'img_classifier_model_%s.h5' %v
    history_file = 'img_classifier_history_%s.json' %v
    
    def save_model_and_weights():
        model.save(model_file)
        model.save_weights(model_weights_file)
        
        return 'Saved model and weights to disk!'

    def save_model_history(m):
        with open(history_file, 'wb') as history_json_file:
            json.dump(m.history, history_json_file)
        
        return 'Saved model history to disk!'
    
    def visualise_accuracy(m):
        plt.plot(m.history['acc'])
        plt.plot(m.history['val_acc'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'validation'], loc='upper left')
        plt.show()
      
    def visualise_loss(m):
        plt.plot(m.history['loss'])
        plt.plot(m.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'validation'], loc='upper left')
        plt.show()
    
    def model_callbacks():
        checkpoint = ModelCheckpoint(epoch_weights_file, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
        early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=early_stopping_patience, verbose=1, mode='auto')
        lr_tracker = SGDLearningRateTracker()
        
        return [checkpoint,early_stopping,lr_tracker]
        
    callbacks_list = model_callbacks()

    m = model.fit(train_data,train_labels,batch_size=batch_size,nb_epoch=nb_epoch,verbose=1,shuffle=True,validation_data=(val_data,val_labels),callbacks=callbacks_list)
    
    print save_model_and_weights()
    print save_model_history(m)
    
    visualise_accuracy(m)
    visualise_loss(m)
    
    return m

# %%
def evaluate_model(m, weights, test_data = test_data, test_labels = test_labels):    
    def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.title(title)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)

        if normalize:
            cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, cm[i, j],
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
     
    plt.close('all')

    m.load_weights(weights)
    m.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    
    print "Done compiling model."
    
    prediction = m.predict(test_data)
    prediction_labels = np_utils.to_categorical(np.argmax(prediction, axis=1), nb_classes)
    
    print 'Accuracy on test data:', accuracy_score(test_labels, prediction_labels)

    print 'Classification Report'
    print classification_report(test_labels, prediction_labels, target_names = class_names)

    # Compute confusion matrix
    cnf_matrix = confusion_matrix(np.argmax(test_labels, axis=1), np.argmax(prediction, axis=1))
    np.set_printoptions(precision=2)

    # Plot non-normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes = class_names, normalize=False, title='Confusion matrix')

    plt.show()

# %%
def get_activations(model, layer, X_batch):
    get_activations = K.function([model.layers[0].input, K.learning_phase()], [model.layers[layer].output,])
    activations = get_activations([X_batch,0])
    return activations

# %%
#load data
train_data, train_labels, test_data, test_labels, val_data, val_labels = load_dataset()
# Out:
# Loaded image set 1 of 32.
# Loaded image set 2 of 32.
# Loaded image set 3 of 32.
# Loaded image set 4 of 32.
# Loaded image set 5 of 32.
# Loaded image set 6 of 32.
# Loaded image set 7 of 32.
# Loaded image set 8 of 32.
# Loaded image set 9 of 32.
# Loaded image set 10 of 32.
# Loaded image set 11 of 32.
# Loaded image set 12 of 32.
# Loaded image set 13 of 32.
# Loaded image set 14 of 32.
# Loaded image set 15 of 32.
# Loaded image set 16 of 32.
# Loaded image set 17 of 32.
# Loaded image set 18 of 32.
# Loaded image set 19 of 32.
# Loaded image set 20 of 32.
# Loaded image set 21 of 32.
# Loaded image set 22 of 32.
# Reshaped images.
# Executed imagewise 3d scaling.
# Loaded labels.
# Loaded image set 23 of 32.
# Loaded image set 24 of 32.
# Loaded image set 25 of 32.
# Loaded image set 26 of 32.
# Loaded image set 27 of 32.
# Reshaped images.
# Executed imagewise 3d scaling.
# Loaded labels.
# Loaded image set 28 of 32.
# Loaded image set 29 of 32.
# Loaded image set 30 of 32.
# Loaded image set 31 of 32.
# Loaded image set 32 of 32.
# Reshaped images.
# Executed imagewise 3d scaling.
# Loaded labels.
# Done.

# %%
#build model
model = build_cnn()
# Out:
# Done.

# %%
# train_data = train_data[:300]
# train_labels  = train_labels[:300]
# val_data =  val_data[:80]
# val_labels = val_labels[:80]

# %%
#fit model
fit_model(model, model_version)
# Out:
# Train on 2109 samples, validate on 435 samples
# Epoch 1/300
# 2080/2109 [============================>.] - ETA: 13s - loss: 1.0626 - acc: 0.4596Epoch 00000: val_acc improved from -inf to 0.31264, saving model to img_classifier_weights_v3_00_0.31.hdf5
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 1022s - loss: 1.0595 - acc: 0.4628 - val_loss: 1.2246 - val_acc: 0.3126
# Epoch 2/300
# 2080/2109 [============================>.] - ETA: 11s - loss: 0.9945 - acc: 0.5654Epoch 00001: val_acc improved from 0.31264 to 0.48046, saving model to img_classifier_weights_v3_01_0.48.hdf5
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 888s - loss: 0.9934 - acc: 0.5666 - val_loss: 0.9776 - val_acc: 0.4805
# Epoch 3/300
# 2080/2109 [============================>.] - ETA: 11s - loss: 0.7665 - acc: 0.6654Epoch 00002: val_acc improved from 0.48046 to 0.70115, saving model to img_classifier_weights_v3_02_0.70.hdf5
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 867s - loss: 0.7632 - acc: 0.6667 - val_loss: 0.7637 - val_acc: 0.7011
# Epoch 4/300
# 2080/2109 [============================>.] - ETA: 10s - loss: 0.5612 - acc: 0.7760Epoch 00003: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 818s - loss: 0.5657 - acc: 0.7748 - val_loss: 0.8496 - val_acc: 0.6184
# Epoch 5/300
# 2080/2109 [============================>.] - ETA: 10s - loss: 0.3845 - acc: 0.8548Epoch 00004: val_acc improved from 0.70115 to 0.71954, saving model to img_classifier_weights_v3_04_0.72.hdf5
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 785s - loss: 0.3829 - acc: 0.8549 - val_loss: 0.6648 - val_acc: 0.7195
# Epoch 6/300
# 2080/2109 [============================>.] - ETA: 10s - loss: 0.3045 - acc: 0.8803Epoch 00005: val_acc improved from 0.71954 to 0.72644, saving model to img_classifier_weights_v3_05_0.73.hdf5
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 783s - loss: 0.3030 - acc: 0.8810 - val_loss: 0.7492 - val_acc: 0.7264
# Epoch 7/300
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.2316 - acc: 0.9111 Epoch 00006: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 782s - loss: 0.2326 - acc: 0.9104 - val_loss: 0.7764 - val_acc: 0.7149
# Epoch 8/300
# 2080/2109 [============================>.] - ETA: 10s - loss: 0.2559 - acc: 0.9029Epoch 00007: val_acc improved from 0.72644 to 0.74943, saving model to img_classifier_weights_v3_07_0.75.hdf5
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 858s - loss: 0.2560 - acc: 0.9028 - val_loss: 0.6982 - val_acc: 0.7494
# Epoch 9/300
# 2080/2109 [============================>.] - ETA: 12s - loss: 0.1789 - acc: 0.9279Epoch 00008: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 998s - loss: 0.1806 - acc: 0.9279 - val_loss: 0.7680 - val_acc: 0.7402
# Epoch 10/300
# 2080/2109 [============================>.] - ETA: 11s - loss: 0.1733 - acc: 0.9284Epoch 00009: val_acc improved from 0.74943 to 0.75632, saving model to img_classifier_weights_v3_09_0.76.hdf5
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 936s - loss: 0.1720 - acc: 0.9289 - val_loss: 0.7234 - val_acc: 0.7563
# Epoch 11/300
# 2080/2109 [============================>.] - ETA: 11s - loss: 0.1637 - acc: 0.9303Epoch 00010: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 872s - loss: 0.1624 - acc: 0.9312 - val_loss: 1.1416 - val_acc: 0.7218
# Epoch 12/300
# 2080/2109 [============================>.] - ETA: 11s - loss: 0.1406 - acc: 0.9423Epoch 00011: val_acc improved from 0.75632 to 0.78851, saving model to img_classifier_weights_v3_11_0.79.hdf5
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 917s - loss: 0.1394 - acc: 0.9431 - val_loss: 0.6858 - val_acc: 0.7885
# Epoch 13/300
# 2080/2109 [============================>.] - ETA: 12s - loss: 0.1591 - acc: 0.9337Epoch 00012: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 952s - loss: 0.1577 - acc: 0.9346 - val_loss: 0.8836 - val_acc: 0.7632
# Epoch 14/300
# 2080/2109 [============================>.] - ETA: 11s - loss: 0.1022 - acc: 0.9582Epoch 00013: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 878s - loss: 0.1013 - acc: 0.9583 - val_loss: 0.9369 - val_acc: 0.7609
# Epoch 15/300
# 2080/2109 [============================>.] - ETA: 10s - loss: 0.1231 - acc: 0.9534Epoch 00014: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 828s - loss: 0.1241 - acc: 0.9526 - val_loss: 0.8096 - val_acc: 0.7264
# Epoch 16/300
# 2080/2109 [============================>.] - ETA: 11s - loss: 0.0977 - acc: 0.9620Epoch 00015: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 883s - loss: 0.0969 - acc: 0.9625 - val_loss: 0.9003 - val_acc: 0.7195
# Epoch 17/300
# 2080/2109 [============================>.] - ETA: 11s - loss: 0.0971 - acc: 0.9635Epoch 00016: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 893s - loss: 0.0974 - acc: 0.9630 - val_loss: 0.8135 - val_acc: 0.7793
# Epoch 18/300
# 2080/2109 [============================>.] - ETA: 11s - loss: 0.1101 - acc: 0.9543Epoch 00017: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 888s - loss: 0.1091 - acc: 0.9550 - val_loss: 1.0118 - val_acc: 0.7609
# Epoch 19/300
# 2080/2109 [============================>.] - ETA: 11s - loss: 0.0833 - acc: 0.9659Epoch 00018: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 887s - loss: 0.0827 - acc: 0.9663 - val_loss: 0.9325 - val_acc: 0.7678
# Epoch 20/300
# 2080/2109 [============================>.] - ETA: 10s - loss: 0.0892 - acc: 0.9663Epoch 00019: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 802s - loss: 0.0895 - acc: 0.9663 - val_loss: 0.9925 - val_acc: 0.7586
# Epoch 21/300
# 2080/2109 [============================>.] - ETA: 10s - loss: 0.0720 - acc: 0.9731Epoch 00020: val_acc improved from 0.78851 to 0.79310, saving model to img_classifier_weights_v3_20_0.79.hdf5
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 798s - loss: 0.0721 - acc: 0.9730 - val_loss: 0.8823 - val_acc: 0.7931
# Epoch 22/300
# 2080/2109 [============================>.] - ETA: 11s - loss: 0.0635 - acc: 0.9750Epoch 00021: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 919s - loss: 0.0634 - acc: 0.9749 - val_loss: 0.9752 - val_acc: 0.7885
# Epoch 23/300
# 2080/2109 [============================>.] - ETA: 10s - loss: 0.0702 - acc: 0.9721Epoch 00022: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 795s - loss: 0.0700 - acc: 0.9720 - val_loss: 1.1634 - val_acc: 0.7747
# Epoch 24/300
# 2080/2109 [============================>.] - ETA: 10s - loss: 0.0552 - acc: 0.9774Epoch 00023: val_acc improved from 0.79310 to 0.80920, saving model to img_classifier_weights_v3_23_0.81.hdf5
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 847s - loss: 0.0546 - acc: 0.9777 - val_loss: 1.0823 - val_acc: 0.8092
# Epoch 25/300
# 2080/2109 [============================>.] - ETA: 10s - loss: 0.0776 - acc: 0.9712Epoch 00024: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 804s - loss: 0.0767 - acc: 0.9716 - val_loss: 1.3327 - val_acc: 0.7448
# Epoch 26/300
# 2080/2109 [============================>.] - ETA: 10s - loss: 0.0553 - acc: 0.9798Epoch 00025: val_acc did not improve
#
# LR: 1.000000
#
# 2109/2109 [==============================] - 803s - loss: 0.0546 - acc: 0.9801 - val_loss: 1.2623 - val_acc: 0.7540
# Epoch 00025: early stopping
# Saved model and weights to disk!
# Saved model history to disk!

# %%
model.load_weights("img_classifier_weights_v3_05_0.73.hdf5")

fit_model(model, model_version)
# Out:
# Train on 2109 samples, validate on 435 samples
# Epoch 1/30
# 2080/2109 [============================>.] - ETA: 10s - loss: 0.2681 - acc: 0.9072Epoch 00000: val_acc improved from -inf to 0.73793, saving model to img_classifier_weights_v4_00_0.74.hdf5
#
# LR: 0.003000
#
# 2109/2109 [==============================] - 802s - loss: 0.2666 - acc: 0.9075 - val_loss: 0.6845 - val_acc: 0.7379
# Epoch 2/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.2048 - acc: 0.9236 Epoch 00001: val_acc did not improve
#
# LR: 0.003000
#
# 2109/2109 [==============================] - 776s - loss: 0.2084 - acc: 0.9237 - val_loss: 0.6728 - val_acc: 0.7310
# Epoch 3/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.2032 - acc: 0.9212 Epoch 00002: val_acc did not improve
#
# LR: 0.002999
#
# 2109/2109 [==============================] - 776s - loss: 0.2034 - acc: 0.9213 - val_loss: 0.9729 - val_acc: 0.7287
# Epoch 4/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.2210 - acc: 0.9144 Epoch 00003: val_acc improved from 0.73793 to 0.75402, saving model to img_classifier_weights_v4_03_0.75.hdf5
#
# LR: 0.002999
#
# 2109/2109 [==============================] - 765s - loss: 0.2219 - acc: 0.9132 - val_loss: 0.6631 - val_acc: 0.7540
# Epoch 5/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.1790 - acc: 0.9303 Epoch 00004: val_acc did not improve
#
# LR: 0.002999
#
# 2109/2109 [==============================] - 776s - loss: 0.1779 - acc: 0.9308 - val_loss: 0.7617 - val_acc: 0.7494
# Epoch 6/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.1536 - acc: 0.9361 Epoch 00005: val_acc did not improve
#
# LR: 0.002999
#
# 2109/2109 [==============================] - 769s - loss: 0.1530 - acc: 0.9365 - val_loss: 0.8134 - val_acc: 0.7264
# Epoch 7/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.1463 - acc: 0.9399 Epoch 00006: val_acc improved from 0.75402 to 0.75632, saving model to img_classifier_weights_v4_06_0.76.hdf5
#
# LR: 0.002999
#
# 2109/2109 [==============================] - 773s - loss: 0.1453 - acc: 0.9407 - val_loss: 0.8067 - val_acc: 0.7563
# Epoch 8/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.1417 - acc: 0.9394 Epoch 00007: val_acc improved from 0.75632 to 0.75862, saving model to img_classifier_weights_v4_07_0.76.hdf5
#
# LR: 0.002998
#
# 2109/2109 [==============================] - 774s - loss: 0.1403 - acc: 0.9403 - val_loss: 0.8496 - val_acc: 0.7586
# Epoch 9/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.1319 - acc: 0.9490 Epoch 00008: val_acc did not improve
#
# LR: 0.002998
#
# 2109/2109 [==============================] - 777s - loss: 0.1322 - acc: 0.9493 - val_loss: 0.8878 - val_acc: 0.7494
# Epoch 10/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.1260 - acc: 0.9476 Epoch 00009: val_acc did not improve
#
# LR: 0.002998
#
# 2109/2109 [==============================] - 785s - loss: 0.1248 - acc: 0.9483 - val_loss: 0.8537 - val_acc: 0.7517
# Epoch 11/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.1160 - acc: 0.9548 Epoch 00010: val_acc improved from 0.75862 to 0.76322, saving model to img_classifier_weights_v4_10_0.76.hdf5
#
# LR: 0.002998
#
# 2109/2109 [==============================] - 762s - loss: 0.1155 - acc: 0.9550 - val_loss: 0.8491 - val_acc: 0.7632
# Epoch 12/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.1072 - acc: 0.9548 Epoch 00011: val_acc did not improve
#
# LR: 0.002998
#
# 2109/2109 [==============================] - 780s - loss: 0.1061 - acc: 0.9554 - val_loss: 1.0660 - val_acc: 0.7609
# Epoch 13/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.0972 - acc: 0.9606 Epoch 00012: val_acc did not improve
#
# LR: 0.002997
#
# 2109/2109 [==============================] - 779s - loss: 0.0974 - acc: 0.9606 - val_loss: 1.0924 - val_acc: 0.7287
# Epoch 14/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.1049 - acc: 0.9577 Epoch 00013: val_acc did not improve
#
# LR: 0.002997
#
# 2109/2109 [==============================] - 778s - loss: 0.1038 - acc: 0.9583 - val_loss: 0.9707 - val_acc: 0.7609
# Epoch 15/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.0938 - acc: 0.9606 Epoch 00014: val_acc improved from 0.76322 to 0.77701, saving model to img_classifier_weights_v4_14_0.78.hdf5
#
# LR: 0.002997
#
# 2109/2109 [==============================] - 769s - loss: 0.0932 - acc: 0.9611 - val_loss: 1.1583 - val_acc: 0.7770
# Epoch 16/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.0868 - acc: 0.9659 Epoch 00015: val_acc did not improve
#
# LR: 0.002997
#
# 2109/2109 [==============================] - 773s - loss: 0.0861 - acc: 0.9663 - val_loss: 0.9960 - val_acc: 0.7770
# Epoch 17/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.0886 - acc: 0.9644 Epoch 00016: val_acc did not improve
#
# LR: 0.002997
#
# 2109/2109 [==============================] - 767s - loss: 0.0887 - acc: 0.9640 - val_loss: 1.1045 - val_acc: 0.7494
# Epoch 18/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.0731 - acc: 0.9692 Epoch 00017: val_acc did not improve
#
# LR: 0.002996
#
# 2109/2109 [==============================] - 780s - loss: 0.0725 - acc: 0.9697 - val_loss: 1.0994 - val_acc: 0.7678
# Epoch 19/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.0785 - acc: 0.9663 Epoch 00018: val_acc did not improve
#
# LR: 0.002996
#
# 2109/2109 [==============================] - 772s - loss: 0.0784 - acc: 0.9663 - val_loss: 1.3596 - val_acc: 0.7471
# Epoch 20/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.0821 - acc: 0.9663 Epoch 00019: val_acc did not improve
#
# LR: 0.002996
#
# 2109/2109 [==============================] - 775s - loss: 0.0813 - acc: 0.9668 - val_loss: 1.1660 - val_acc: 0.7655
# Epoch 21/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.0807 - acc: 0.9659 Epoch 00020: val_acc did not improve
#
# LR: 0.002996
#
# 2109/2109 [==============================] - 773s - loss: 0.0806 - acc: 0.9659 - val_loss: 1.0803 - val_acc: 0.7747
# Epoch 22/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.0684 - acc: 0.9745 Epoch 00021: val_acc did not improve
#
# LR: 0.002996
#
# 2109/2109 [==============================] - 761s - loss: 0.0684 - acc: 0.9744 - val_loss: 1.0270 - val_acc: 0.7586
# Epoch 23/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.0836 - acc: 0.9635 Epoch 00022: val_acc did not improve
#
# LR: 0.002995
#
# 2109/2109 [==============================] - 784s - loss: 0.0829 - acc: 0.9635 - val_loss: 1.2550 - val_acc: 0.7678
# Epoch 24/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.0708 - acc: 0.9745 Epoch 00023: val_acc did not improve
#
# LR: 0.002995
#
# 2109/2109 [==============================] - 773s - loss: 0.0701 - acc: 0.9749 - val_loss: 1.1773 - val_acc: 0.7609
# Epoch 25/30
# 2080/2109 [============================>.] - ETA: 9s - loss: 0.0720 - acc: 0.9712 Epoch 00024: val_acc improved from 0.77701 to 0.78161, saving model to img_classifier_weights_v4_24_0.78.hdf5
#
# LR: 0.002995
#
# 2109/2109 [==============================] - 763s - loss: 0.0719 - acc: 0.9711 - val_loss: 1.1761 - val_acc: 0.7816
# Epoch 00024: early stopping
# Saved model and weights to disk!
# Saved model history to disk!

# %%
loaded_model = build_cnn()
evaluate_model(loaded_model, 'img_classifier_weights_v3_23_0.81.hdf5')
# Out:
# Done building model.
# Done compiling model.
# Accuracy on test data: 0.816631130064
# Classification Report
#              precision    recall  f1-score   support
#
#          CN       0.88      0.93      0.90       159
#         MCI       0.73      0.79      0.76       157
#          AD       0.86      0.73      0.79       153
#
# avg / total       0.82      0.82      0.82       469

# %%
i = 0

X = test_data[i:i+1]

W = np.array(get_activations(model, 2, X))

W = np.squeeze(W)

print W.shape

plt.close('all')

c = 0

for w in W:
    print w.shape
    X, Y = np.meshgrid(np.linspace(0,1,w.shape[1]), np.linspace(0,1,w.shape[2]))

    zlim = float(w.shape[0] - 1)

    # create the figure
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.set_zlim((0.,zlim))
    ax.axis('off')

    for i, d in enumerate(w):
        ax.contourf(X, Y, d, 100, zdir='z', offset=i, interpolation='nearest', cmap=scan_cmap, aspect='equal')
        
    plt.savefig('img_c2_%s_2.png' %c, transparent=True)
    plt.close('all')
    c += 1
# Out:
# (8, 28, 45, 45)
# (28, 45, 45)
# (28, 45, 45)
# (28, 45, 45)
# (28, 45, 45)
# (28, 45, 45)
# (28, 45, 45)
# (28, 45, 45)
# (28, 45, 45)

# %%
# Visualize weights
W = model.layers[0].W.get_value(borrow=True)
W = np.squeeze(W)

plot_x = 1
plot_y = 3

plot_range = plot_x * plot_y

for i, w in enumerate(W):
    print 'Filters %s' %i
    
    
    X, Y = np.meshgrid(np.linspace(0,1,w.shape[1]), np.linspace(0,1,w.shape[2]))

    zlim = float(w.shape[0] - 1)

    # create the figure
    fig = plt.figure()
    
    fig, axs = plt.subplots(plot_x,plot_y, figsize=(5, 5))
    fig.subplots_adjust(hspace = .5, wspace=.1)

    for ax, d in zip(axs.ravel(), range(plot_range)): ax.axis('off')

    i = 0
    for ax, d in zip(axs.ravel(), w):
        i = i + 1
        ax.imshow(d, interpolation='nearest', cmap=cm.binary)
        ax.set_title(str(i))
    c += 1
    
    plt.show()
    plt.close('all')
# Out:
# Filters 0
# Filters 1
# Filters 2
# Filters 3
# Filters 4
# Filters 5
# Filters 6
# Filters 7

# %%
demographics = np.asarray(pd.read_csv('adni_demographic_master_kaggle.csv'))

def get_subject(subject_id):
    scan_range = train_data[subject_id][0]
    demographic = demographics[subject_id]
    
    return demographic, scan_range

# %%
print score
# Out:
# [0.34275584100787321, 0.87846481990712533]

# %%
subject = get_subject(0)

print "Subject:", subject[0]

plt.close('all')

plot_x = 8
plot_y = 8

plot_range = plot_x * plot_y

fig, axs = plt.subplots(plot_x,plot_y, figsize=(10, 10))
fig.subplots_adjust(hspace = .5, wspace=.001)

for ax, d in zip(axs.ravel(), range(plot_range)): ax.axis('off')
    
i = 0
for ax, d in zip(axs.ravel(), subject[1]):
    i = i + 1
    ax.imshow(d, interpolation='nearest', vmin=0, vmax=1, cmap=cm.binary)
    ax.set_title(str(i))

plt.show()
# Out:
# Subject: [0 20051021 2 'F' 70.9973]

# %%
subject = get_subject(0)

print "Subject:", subject[0]

X, Y = np.meshgrid(np.linspace(0,1,subject[1].shape[1]), np.linspace(0,1,subject[1].shape[2]))
zlim = float(subject[1].shape[0] - 1)

# create the figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlim((0.,zlim))
ax.axis('off')
ax.set_title("3D Projection.")
        
for  i, d in enumerate(subject[1]):
    ax.contourf(X, Y, d, 100, zdir='z', offset=i, cmap=scan_cmap, aspect='equal')

plt.show()
# Out:
# Subject: [0 20051021 2 'F' 70.9973]
